# %%
import tifffile as tiff
import numpy as np
import matplotlib.pyplot as plt

# %%
img = tiff.imread('/pscratch/sd/h/hasitha/emsl/out_astra_fdk_3/reco0999.tif')
print(img.max())
print(img.min())
# Out:
# 0.6495077
# -0.027750272

# %%
# plt.imshow(img[500:1500,500:1500], cmap='gray')
plt.figure(figsize=(15, 15))
plt.imshow(img, cmap='gray', vmax = 0.25, vmin = -0.03)
plt.imsave('./img.jpeg',img, cmap = 'gray')

# %%
proj = tiff.imread('/pscratch/sd/h/hasitha/emsl/projections/61273 Yang_MONet Core 1 A bot_1000.tif')
print(proj.max())
print(proj.min())
# Out:
# 63551
# 1756

# %%
plt.imshow(proj[100,:,:], cmap='gray')
